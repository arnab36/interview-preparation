# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# x axis values
x = np.arange(0, 1, 0.0001)
# corresponding y axis values
y = []
for i in x:
    y.append(i*i)

# %%
 # plotting the points 
plt.plot(x, y)
 
# naming the x axis
plt.xlabel('x - axis')
# naming the y axis
plt.ylabel('y - axis')
 
# giving a title to my graph
plt.title('My first graph!')
 
# function to show the plot
plt.show()

# %%
area = 0
l = len(x)

# Considering each smaller area as Trapezium
for i in range(0,l-1):
    tmp = 0.5 * (y[i] + y[i+1]) * (x[i+1] - x[i])
    area = area + tmp

# %%
area
# Out:
# 0.33323334499949997

# %%
area = 0
l = len(x)
# Considering each smaller area as Rectangle
for i in range(0,l-1):
    tmp = (y[i+1]) * (x[i+1] - x[i])
    area = area + tmp

# %%
area
# Out:
# 0.3332833350000001
