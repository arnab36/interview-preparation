# %%
pip install statsmodels
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
from datetime import datetime
# %matplotlib inline

# %%
import statsmodels.api as sm
from statsmodels.tsa.stattools import acovf, acf,pacf,pacf_yw, pacf_ols

# %%
df1 = pd.read_csv('../../Time-series-analysis/Data/airline_passengers.csv',index_col='Month', parse_dates=True)

# %%
df1.index.freq = 'MS'

# %%
df2 = pd.read_csv('../../Time-series-analysis/Data/DailyTotalFemaleBirths.csv',index_col='Date', parse_dates=True)

# %%
df2.index.freq = 'D'

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from pandas.plotting import lag_plot

# %%
lag_plot(df['Thousands of Passengers'])
# Out:
# <Axes: xlabel='y(t)', ylabel='y(t + 1)'>

# %%
lag_plot(df2['Births'])
# Out:
# <Axes: xlabel='y(t)', ylabel='y(t + 1)'>

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
plot_acf(df1,lags=40);

# %%
plot_acf(df2,lags=40);

# %%
plot_pacf(df2,lags=40);

# %%
plot_pacf(df1,lags=40);
